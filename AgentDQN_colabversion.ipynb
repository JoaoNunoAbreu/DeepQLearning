# %% [markdown]
# <a href="https://colab.research.google.com/github/beatrizfrocha/DeepQLearning/blob/master/AgentDQN_colabversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mount google drive

# %%
if 'google.colab' in str(get_ipython()):
  from google.colab import drive

  drive.mount('/content/drive')
  print('Running on CoLab')
else:
  print('Not running on CoLab')
# Out:
# Mounted at /content/drive
# Running on CoLab

# %% [markdown]
# Import ROMS

# %%
# !unrar e Roms.rar
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Roms.rar
#
#   OK
#   OK
# All OK

# %%
# !unzip ROMS.zip
# Out:
# Archive:  ROMS.zip
#    creating: ROMS/
#   inflating: ROMS/128 in 1 Game Select ROM (128 in 1) (Unknown) ~.bin
#   inflating: ROMS/2 Pak Special - Cavern Blaster, City War (1992) (HES) (773-867) (PAL).bin
#   inflating: ROMS/2 Pak Special - Challenge, Surfing (1990) (HES) (771-333) (PAL).bin
#   inflating: ROMS/2 Pak Special - Dolphin, Oink (1990) (HES) (771-341) (PAL).bin
#   inflating: ROMS/2 Pak Special - Dolphin, Pigs n' Wolf (1990) (HES) (771-341) (PAL).bin
#   inflating: ROMS/2 Pak Special - Dungeon Master, Creature Strike (1992) (HES) (773-891) (PAL).bin
#   inflating: ROMS/2 Pak Special - Hoppy, Alien Force (1992) (HES) (773-875) (PAL).bin
#   inflating: ROMS/2 Pak Special - Moto-Cross, Boom Bang (1990) (HES) (701-157) (PAL).bin
#   inflating: ROMS/2 Pak Special - Space Voyage, Fire Alert (1992) (HES) (773-883) (PAL).bin
#   inflating: ROMS/2 Pak Special - Star Warrior, Frogger (1990) (HES) (771-422) (PAL).bin
# ...

# %%
# !python -m atari_py.import_roms ROMS
# Out:
# copying qbert.bin from ROMS/Q. Bert (1983) (CCE) (C-822).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/qbert.bin
# copying breakout.bin from ROMS/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/breakout.bin
# copying tennis.bin from ROMS/Tennis - Le Tennis (1981) (Activision, Alan Miller) (AG-007, CAG-007) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/tennis.bin
# copying defender.bin from ROMS/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/defender.bin
# copying keystone_kapers.bin from ROMS/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/keystone_kapers.bin
# ...

# %% [markdown]
# Import script

# %%
import agentDQN

# %% [markdown]
# Change TRAIN_DIR

# %%
if 'google.colab' in str(get_ipython()):
  print('Running on CoLab')
  agentDQN.TRAIN_DIR = '/content/drive/MyDrive/models'
else:
  print('Not running on CoLab')
# Out:
# Running on CoLab

# %% [markdown]
# Train

# %%
agentDQN.train({'--mode': 'resume'})
# Out:
# state: observe, episode: 0, score: 2.0, global_step: 207, avg loss: 0.0, step: 207, memory length: 207
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# state: observe, episode: 1, score: 1.0, global_step: 383, avg loss: 0.0, step: 176, memory length: 383
# state: observe, episode: 2, score: 0.0, global_step: 515, avg loss: 0.0, step: 132, memory length: 515
# state: observe, episode: 3, score: 1.0, global_step: 689, avg loss: 0.0, step: 174, memory length: 689
# state: observe, episode: 4, score: 2.0, global_step: 885, avg loss: 0.0, step: 196, memory length: 885
# state: observe, episode: 5, score: 1.0, global_step: 1010, avg loss: 0.0, step: 125, memory length: 1010
# ...
